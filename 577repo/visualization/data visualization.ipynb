# %% [markdown]
# # US Colleges and Universities Data Visualization

# %% [markdown]
# doing data visualization on all of US undergrad and grad schools
#
# link: https://www.kaggle.com/datasets/mexwell/us-colleges-and-universities?resource=download

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
colleges = pd.read_csv("C:/Users/faith/OneDrive/Documents/us-colleges-and-universities.csv",encoding='ISO-8859-1', delimiter=';')
colleges.head(10)
# Out:
#                              ï»¿Geo Point  \
# 0  45.48038428000007, -122.67453292999994
# 1                   42.388647, -72.529312
# 2  39.24427778200004, -119.93912465099999
# 3       33.13142857200006, -117.118565978
# 4                    26.70538, -80.136711
# 5   38.72876088500004, -90.38025209799997
# 6                    33.937727, -83.37143
# 7                   33.463987, -86.908933
# 8                    41.33127, -74.159642
# 9                   47.64894, -122.377121
#
#                                            Geo Shape  OBJECTID  IPEDSID  \
# 0  {"coordinates": [-122.67453292999994, 45.48038...        16   443599
# 1  {"coordinates": [-72.529312, 42.388647], "type...        23   166629
# 2  {"coordinates": [-119.93912465099999, 39.24427...        28   182458
# 3  {"coordinates": [-117.118565978, 33.1314285720...        81   468848
# 4  {"coordinates": [-80.136711, 26.70538], "type"...       110   487393
# ...

# %%
colleges.info()
colleges.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6559 entries, 0 to 6558
# Data columns (total 45 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ï»¿Geo Point  6559 non-null   object
#  1   Geo Shape     6559 non-null   object
#  2   OBJECTID      6559 non-null   int64
#  3   IPEDSID       6559 non-null   int64
#  4   NAME          6559 non-null   object
#  5   ADDRESS       6558 non-null   object
#  6   CITY          6559 non-null   object
#  7   STATE         6559 non-null   object
#  8   ZIP           6559 non-null   int64
#  9   ZIP4          6559 non-null   object
#  10  TELEPHONE     6559 non-null   object
#  11  TYPE          6559 non-null   int64
#  12  STATUS        6559 non-null   object
#  13  POPULATION    6559 non-null   int64
#  14  COUNTY        6559 non-null   object
#  15  COUNTYFIPS    6559 non-null   object
#  16  COUNTRY       6559 non-null   object
#  17  LATITUDE      6559 non-null   float64
# ...

# %% [markdown]
# We are now going to apply the Perceptron onto this model.

# %%
print('colleges.HOUSING == "2"')
# Out:
# colleges.HOUSING == "2"
