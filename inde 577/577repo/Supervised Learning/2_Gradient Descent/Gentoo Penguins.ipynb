# %% [markdown]
# #Predicting Student Performance with Linear Regression and Gradient Descent

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import seaborn as sns
sns.set_theme()

df=pd.read_csv(r"C:\Users\faith\inde 577\577repo\Supervised Learning\Datasets\palmer_penguins.csv")
plt.figure(figsize = (10, 8))
plt.scatter(df.traveltime, 
            df.absences, 
            color = "lightseagreen",
            label = "setosa flowers")
plt.xlabel("travel [cm]", fontsize = 15)
plt.ylabel("absences[cm]", fontsize = 15)
plt.legend(fontsize = 15)
plt.title("My Regression Data", fontsize = 18)
plt.show()
